# %% [markdown]
# #  Spacial interceptions

# %% [markdown]
# 1. Find the census block shape files online (American Fact Finder has them), http://www1.nyc.gov/ has them. The folder you should download is names nycb2010_16d.
# Load it as a geopandas file

# %%
# a view of the shape file loaded as a geojson file will look like this. Notice the coordinates. They are in 
# epsg=2263 is US feet. You want to convert them in epsg=4326: lat/on . 
# Look at the notebook https://github.com/fedhere/PUI2016_fb55/blob/master/Lab9_SRK325/GeospatialAnalysis_CitiBike.ipynb
ct_shape.head()
# Out:
#      BCTCB2010 BoroCode       BoroName CB2010  CT2010     Shape_Area  \
# 0  50009001000        5  Staten Island   1000  000900  244589.603884
# 1  50020011000        5  Staten Island   1000  002001  111006.286826
# 2  50027001000        5  Staten Island   1000  002700  150406.766022
# 3  50040001000        5  Staten Island   1000  004000  141296.561149
# 4  50064001000        5  Staten Island   1000  006400  200784.983607
#
#     Shape_Leng                                           geometry
# 0  2508.948115  POLYGON ((962269.1260375977 173705.5001831055,...
# 1  1345.886422  POLYGON ((964642.2676391602 161835.2651977539,...
# 2  1703.381172  POLYGON ((963363.1168212891 167356.3336181641,...
# 3  1511.173743  POLYGON ((960069.9965820312 161953.6936035156,...
# 4  1978.243852  POLYGON ((963023.891784668 158246.7521972656, ...

# %% [markdown]
# 2.. Extract only the Brooklyn shape polygons and convert the coordinates to lat/lon

# %%
ct_latlon.head()
# Out:
#         BCTCB2010 BoroCode  BoroName CB2010  CT2010     Shape_Area  \
# 5037  30002001000        3  Brooklyn   1000  000200  208484.989566
# 5038  30003011000        3  Brooklyn   1000  000301   63365.958361
# 5039  30005011000        3  Brooklyn   1000  000501  116303.194723
# 5040  30011001000        3  Brooklyn   1000  001100   54802.306859
# 5041  30015001000        3  Brooklyn   1000  001500   79196.530872
#
#        Shape_Leng                                           geometry
# 5037  2097.493132  POLYGON ((-74.00659158337982 40.65561273365177...
# 5038  1006.913933  POLYGON ((-73.99514512602698 40.69877384567194...
# 5039  1431.900698  POLYGON ((-73.99270830309769 40.69809925981345...
# 5040   951.657541  POLYGON ((-73.98514306089652 40.6948851429698,...
# 5041  1129.348482  POLYGON ((-73.98305147125492 40.69837793354038...

# %% [markdown]
# 3.. Find the coordinates of CUSP: 1 MetroTech Brooklyn. Create a Point shapely geometry with the coordinates of CUSP
#
#     shapely.geometry.Point()

# %% [markdown]
# 4.. Loop over the Brookly polygons (nearly 10000) and assess find in which geometry the polygon is contained

# %%
# you will need to use 
# - ct_latlon.geometry (the polygons you are looping over)
# - shapely.geometry.asShape(<the polygon>).contain(<the point>)
# - save the index of the polygon that contains the CUSP
for i, ct  in [.....]
    print('CUSP is contained in', ct)
# Out:
# CUSP is contained in POLYGON ((-73.98622595691907 40.69308831340505, -73.98627231669104 40.69219479463375, -73.98729894947923 40.69223407539823, -73.98725396415627 40.69312490273171, -73.98622595691907 40.69308831340505))

# %% [markdown]
# 5.. Plot one every 10 polygons of brooklyn (using the geopandas datafame method plot)
# and overplot the locati`on of cusp as a point (using pylab.scatter)
# Overplot also the census track that contains cusp in red (using the geopandas datafame method plot)

# %%
# Out:
# []
