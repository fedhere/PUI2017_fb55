# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#DATA:" data-toc-modified-id="DATA:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>DATA:</a></div><div class="lev1 toc-item"><a href="#exploration" data-toc-modified-id="exploration-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>exploration</a></div><div class="lev2 toc-item"><a href="#plot-mass-shooting-vs-gdp-in-absolute-numbers,-and-per-person.-Show-the-errorbars-(y-errors)" data-toc-modified-id="plot-mass-shooting-vs-gdp-in-absolute-numbers,-and-per-person.-Show-the-errorbars-(y-errors)-21"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>plot mass shooting vs gdp in absolute numbers, and per person. Show the errorbars (y errors)</a></div><div class="lev2 toc-item"><a href="#plot-the-average-number-of-civilian-fire-arms-per-person" data-toc-modified-id="plot-the-average-number-of-civilian-fire-arms-per-person-22"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>plot the average number of civilian fire arms per person</a></div><div class="lev2 toc-item"><a href="#plot-the-average-number-of-homicide-by-fire-arms-per-person" data-toc-modified-id="plot-the-average-number-of-homicide-by-fire-arms-per-person-23"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>plot the average number of homicide by fire arms per person</a></div><div class="lev2 toc-item"><a href="#plot-the-number-of--homicides-by-fire-arm-against-the-number-of-civilian-firearms.-plot-the--US-in-a-different-color" data-toc-modified-id="plot-the-number-of--homicides-by-fire-arm-against-the-number-of-civilian-firearms.-plot-the--US-in-a-different-color-24"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>plot the number of  homicides by fire arm against the number of civilian firearms. plot the  US in a different color</a></div><div class="lev2 toc-item"><a href="#plot-the-number-of--mass-shootings-against-the-number-of-civilian-firearms.-plot-the--US-in-a-different-color" data-toc-modified-id="plot-the-number-of--mass-shootings-against-the-number-of-civilian-firearms.-plot-the--US-in-a-different-color-25"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>plot the number of  mass shootings against the number of civilian firearms. plot the  US in a different color</a></div><div class="lev1 toc-item"><a href="#Modeling" data-toc-modified-id="Modeling-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Modeling</a></div><div class="lev2 toc-item"><a href="#fit-a-line-to-the-Number-of-mass-shootings--per-person-as-a-function-of-Average-total-all-civilian-firearms-per-person.-Before-you-do-it-it-is-a-good-idea-to-make-sure-that-both-quantities-are-roughly-of-the-same-order-of-magnitude-(unity).-Use" data-toc-modified-id="fit-a-line-to-the-Number-of-mass-shootings--per-person-as-a-function-of-Average-total-all-civilian-firearms-per-person.-Before-you-do-it-it-is-a-good-idea-to-make-sure-that-both-quantities-are-roughly-of-the-same-order-of-magnitude-(unity).-Use-31"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>fit a line to the Number of mass shootings  per person as a function of Average total all civilian firearms per person. Before you do it it is a good idea to make sure that both quantities are roughly of the same order of magnitude (unity). Use</a></div><div class="lev2 toc-item"><a href="#Extra-credit:-calculate-the-confidence-interval-by-hand-and-also-plot-them-(you-can-use-pl.fill_between)" data-toc-modified-id="Extra-credit:-calculate-the-confidence-interval-by-hand-and-also-plot-them-(you-can-use-pl.fill_between)-32"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Extra credit: calculate the confidence interval by hand and also plot them (you can use pl.fill_between)</a></div><div class="lev2 toc-item"><a href="#Use-the-stsatsmodels.gaphics-package-to-plot-the-influence-plot." data-toc-modified-id="Use-the-stsatsmodels.gaphics-package-to-plot-the-influence-plot.-33"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Use the stsatsmodels.gaphics package to plot the influence plot.</a></div><div class="lev2 toc-item"><a href="#Extra-credit:-calculate-from-scratch-the-stanrdardized-residuals-and-the-H-leverage-for-the-WLS-model-and-discuss-if-there-are-any-differences" data-toc-modified-id="Extra-credit:-calculate-from-scratch-the-stanrdardized-residuals-and-the-H-leverage-for-the-WLS-model-and-discuss-if-there-are-any-differences-34"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Extra credit: calculate from scratch the stanrdardized residuals and the H leverage for the WLS model and discuss if there are any differences</a></div><div class="lev1 toc-item"><a href="#Discuss-your-findings" data-toc-modified-id="Discuss-your-findings-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Discuss your findings</a></div>

# %% [markdown]
# **regression exercise**
#
# **written by Federica B Bianco CUSP 2017**
#
# **for PUI lecture on models and linear regression**

# %% [markdown]
# # DATA:
#
# The Guardian firearms murders and ownership data. The relevans sheet is uploaded in the github repository as a csv file. Download it from there. Note: this dataset is from 2012.
#
# **Extra credit**: download directly from google docs with a google API
#
# https://docs.google.com/spreadsheets/d/1chqUZHuY6cXYrRYkuE0uwXisGaYvr7durZHJhpLGycs/edit#gid=0
#
# Number of mass shootings: find the link here https://datawrapper.dwcdn.net/pvLFI/4/
#
# The world population by country find the download link here :
# https://data.worldbank.org/indicator/SP.POP.TOTL
#
# Remember that all read or downloads have to me reproducible.
#
# merge all datasets. After throwing away the irrelevant data it should look something like this (I renamed the GDP and the population as gdp" and "pop")

# %%
df_ = guns.merge(gdpall[[u'Country Name', 'pop', 'gdp']], right_on="Country Name", 
                 left_on="Country/Territory")[["Country Name",
                                               'Average total all civilian firearms', 
                                               "pop",
                                               "gdp",
                                               "Number of homicides by firearm"]]
#.plot(x=u'Homicide by firearm rate per 100,000 pop', y="gdp", kind='scatter')

# %%
df_ = df_.merge(ms, right_on="Country", left_on="Country Name")

# %%
df_.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3ed245e16dfc> in <module>()
# ----> 1 df_.head()
#
# NameError: name 'df_' is not defined

# %% [markdown]
# # exploration
#
# ## plot mass shooting vs gdp in absolute numbers, and per person. Show the errorbars (y errors)
#
# Use Poisson statistics for the errorbars on the number of mass shootings (optional: include errors on the population, also as Poisson statistics)
#
# Are there any points that look like they may be outilers?

# %%
import mpld3
fig, ax = plt.subplots()

scatter = ax.scatter(df_.gdp, df_['Number of mass shootings'])
ax.errorbar(df_.gdp, df_['Number of mass shootings'], 
            yerr = np.sqrt(df_['Number of mass shootings'] * 1.0), fmt = '.')
ax.set_xlabel("GDP per person")
ax.set_ylabel("Number of mass shooting per person")
ax.set_ylim()
labels = ['{0}, {1}'.format(c, n) for c,n in zip(df_["Country"].values, df_["Number of mass shootings"].values)]
tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=labels)
mpld3.plugins.connect(fig, tooltip)
mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el12784722143696970915708"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el12784722143696970915708", {"axes": [{"xlim": [-792833246152.33362, 16962306821245.359], "yscale": "linear", "axesbg": "#EAEAF2", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "GDP per person", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.066894106629205946], "rotation": -0.0, "id": "el12784740372112"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Number of mass shooting per person", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.049563172043010736, 0.5], "rotation": -90.0, "id": "el12784725434832"}], "zoomable": true, "images": [], "xdomain": [-792833246152.33362, 16962306821245.359], "ylim": [-4.3538798354095087, 91.173934233077233], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "visible": true, "fontsize": 10.0, "position": "bottom", "nticks": 11, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "visible": true, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [], "markers": [{"edgecolor": "#4C72B0", "facecolor": "#4C72B0", "edgewidth": 0.0, "yindex": 1, "coordinates": "data", "zorder": 2.1, "markerpath": [[[0.0, 1.75], [0.46410542500000007, 1.75], [0.9092647738734936, 1.565608960279423], [1.2374368670764582, 1.2374368670764582], [1.565608960279423, 0.9092647738734936], [1.75, 0.46410542500000007], [1.75, 0.0], [1.75, -0.46410542500000007], [1.565608960279423, -0.9092647738734936], [1.2374368670764582, -1.2374368670764582], [0.9092647738734936, -1.565608960279423], [0.46410542500000007, -1.75], [0.0, -1.75], [-0.46410542500000007, -1.75], [-0.9092647738734936, -1.565608960279423], [-1.2374368670764582, -1.2374368670764582], [-1.565608960279423, -0.9092647738734936], [-1.75, -0.46410542500000007], [-1.75, 0.0], [-1.75, 0.46410542500000007], [-1.565608960279423, 0.9092647738734936], [-1.2374368670764582, 1.2374368670764582], [-0.9092647738734936, 1.565608960279423], [-0.46410542500000007, 1.75], [0.0, 1.75]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el12784654761296pts"}], "id": "el12784738989200", "ydomain": [-4.3538798354095087, 91.173934233077233], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#4C72B0"], "edgewidths": [0.3], "offsets": "data01", "yindex": 1, "id": "el12784722146128", "pathtransforms": [[7.0, 0.0, 0.0, 7.0, 0.0, 0.0]], "pathcoordinates": "display", "offsetcoordinates": "data", "zorder": 1, "xindex": 0, "alphas": [null], "facecolors": ["#4C72B0"]}, {"paths": [[[[1538194473087.23, 2.0], [1538194473087.23, 6.0]], ["M", "L"]], [[[407451583084.239, 0.0], [407451583084.239, 2.0]], ["M", "L"]], [[[1824288757447.57, 2.0], [1824288757447.57, 6.0]], ["M", "L"]], [[[327148899962.146, 0.0], [327148899962.146, 0.0]], ["M", "L"]], [[[256706466091.089, 0.5857864376269049], [256706466091.089, 3.414213562373095]], ["M", "L"]], [[ ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.js", function(){
#
#          mpld3.draw_figure("fig_el12784722143696970915708", {"axes": [{"xlim": [-792833246152.33362, 16962306821245.359], "yscale": "linear", "axesbg": "#EAEAF2", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "GDP per person", "coordinates": "axes", "zorder": 3, "alpha":

# %%
fig, ax = plt.subplots()

scatter = ax.scatter(df_.gdp / df_['pop'], df_['Number of mass shootings'] / df_['pop'] * 1e7)
ax.errorbar(df_.gdp / df_['pop'], df_['Number of mass shootings'] / df_['pop'] * 1e7, 
            yerr = np.sqrt(df_['Number of mass shootings'] * 1.0) / df_['pop'] * 1e7, fmt = '.')
ax.set_xlabel("GDP per person")
ax.set_ylabel("Number of mass shooting per person - multiplied by 1e7")
labels = ['{0}, {1}'.format(c, n) for c,n in zip(df_["Country"].values, df_["Number of mass shootings"].values)]
tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=labels)
mpld3.plugins.connect(fig, tooltip)
mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el127847480817442072344127"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el127847480817442072344127", {"axes": [{"xlim": [8138.5803571235574, 111444.75675427055], "yscale": "linear", "axesbg": "#EAEAF2", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "GDP per person", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.066894106629205946], "rotation": -0.0, "id": "el12784748202576"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Number of mass shooting per person - multiplied by 1e7", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.049563172043010736, 0.5], "rotation": -90.0, "id": "el12784748205520"}], "zoomable": true, "images": [], "xdomain": [8138.5803571235574, 111444.75675427055], "ylim": [-0.54903673975411316, 11.27222922431393], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "visible": true, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "visible": true, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [], "markers": [{"edgecolor": "#4C72B0", "facecolor": "#4C72B0", "edgewidth": 0.0, "yindex": 1, "coordinates": "data", "zorder": 2.1, "markerpath": [[[0.0, 1.75], [0.46410542500000007, 1.75], [0.9092647738734936, 1.565608960279423], [1.2374368670764582, 1.2374368670764582], [1.565608960279423, 0.9092647738734936], [1.75, 0.46410542500000007], [1.75, 0.0], [1.75, -0.46410542500000007], [1.565608960279423, -0.9092647738734936], [1.2374368670764582, -1.2374368670764582], [0.9092647738734936, -1.565608960279423], [0.46410542500000007, -1.75], [0.0, -1.75], [-0.46410542500000007, -1.75], [-0.9092647738734936, -1.565608960279423], [-1.2374368670764582, -1.2374368670764582], [-1.565608960279423, -0.9092647738734936], [-1.75, -0.46410542500000007], [-1.75, 0.0], [-1.75, 0.46410542500000007], [-1.565608960279423, 0.9092647738734936], [-1.2374368670764582, 1.2374368670764582], [-0.9092647738734936, 1.565608960279423], [-0.46410542500000007, 1.75], [0.0, 1.75]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el12784755767120pts"}], "id": "el12784748182032", "ydomain": [-0.54903673975411316, 11.27222922431393], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#4C72B0"], "edgewidths": [0.3], "offsets": "data01", "yindex": 1, "id": "el12784755764816", "pathtransforms": [[7.0, 0.0, 0.0, 7.0, 0.0, 0.0]], "pathcoordinates": "display", "offsetcoordinates": "data", "zorder": 1, "xindex": 0, "alphas": [null], "facecolors": ["#4C72B0"]}, {"paths": [[[[67677.63476627944, 0.8799620067603962], [67677.63476627944, 2.6398860202811885]], ["M", "L"]], [[[48333.572726737075, 0.0], [48333.572726737075, 2.3724817737053336]], ["M", "L"]], [[[52496.69487047096, 0.575530542038981], [52496.69487047096, 1.7265916261169432]], ["M", "L"]], [[[58507.50020962727, 0.0], [58507.50020962727, 0.0]], ["M", "L ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.

# %%
df_['Average total all civilian firearms'] / df_['pop']
# Out:
# 0     0.134194
# 1     0.296560
# 2     0.286326
# 3     0.116246
# 4     0.443298
# 5     0.289370
# 6     0.310845
# 7     0.226347
# 8     0.056450
# 9     0.280622
# 10    0.078484
# 11    0.117569
# 12    0.005563
# 13    0.131840
# 14    0.209841
# 15    0.278964
# 16    0.013399
# 17    0.085593
# 18    0.096209
# 19    0.294137
# 20    0.425167
# 21    0.859877
# dtype: float64

# %% [markdown]
# ## plot the average number of civilian fire arms per person
# first without errors, then with errors. are there  points that look like outliers?

# %%
fig, ax = plt.subplots()

scatter = ax.scatter(df_.gdp / df_['pop'], 
        df_['Average total all civilian firearms'] / df_['pop'])
ax.errorbar(df_.gdp / df_['pop'], 
        df_['Average total all civilian firearms'] / df_['pop'],
           yerr = np.sqrt(df_['Average total all civilian firearms'] / df_['pop']), 
                         fmt='.')
ax.set_xlabel("GDP per person")
ax.set_ylabel("Average total all civilian firearms per person - multiplied by 1e7")
labels = ['{0}, {1}'.format(c, n) for c,n in zip(df_["Country"].values, df_["Average total all civilian firearms"].values)]
tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=labels)
mpld3.plugins.connect(fig, tooltip)
mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el127847485935524627654312"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el127847485935524627654312", {"axes": [{"xlim": [8138.5803571235574, 111444.75675427055], "yscale": "linear", "axesbg": "#EAEAF2", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "GDP per person", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.066894106629205946], "rotation": -0.0, "id": "el12784740242192"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Average total all civilian firearms per person - multiplied by 1e7", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.081205197132616466, 0.5], "rotation": -90.0, "id": "el12784739595280"}], "zoomable": true, "images": [], "xdomain": [8138.5803571235574, 111444.75675427055], "ylim": [-0.35124161828134925, 1.889001856630123], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "visible": true, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "visible": true, "fontsize": 10.0, "position": "left", "nticks": 11, "tickvalues": null}], "lines": [], "markers": [{"edgecolor": "#4C72B0", "facecolor": "#4C72B0", "edgewidth": 0.0, "yindex": 1, "coordinates": "data", "zorder": 2.1, "markerpath": [[[0.0, 1.75], [0.46410542500000007, 1.75], [0.9092647738734936, 1.565608960279423], [1.2374368670764582, 1.2374368670764582], [1.565608960279423, 0.9092647738734936], [1.75, 0.46410542500000007], [1.75, 0.0], [1.75, -0.46410542500000007], [1.565608960279423, -0.9092647738734936], [1.2374368670764582, -1.2374368670764582], [0.9092647738734936, -1.565608960279423], [0.46410542500000007, -1.75], [0.0, -1.75], [-0.46410542500000007, -1.75], [-0.9092647738734936, -1.565608960279423], [-1.2374368670764582, -1.2374368670764582], [-1.565608960279423, -0.9092647738734936], [-1.75, -0.46410542500000007], [-1.75, 0.0], [-1.75, 0.46410542500000007], [-1.565608960279423, 0.9092647738734936], [-1.2374368670764582, 1.2374368670764582], [-0.9092647738734936, 1.565608960279423], [-0.46410542500000007, 1.75], [0.0, 1.75]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el12784740114704pts"}], "id": "el12784748592976", "ydomain": [-0.35124161828134925, 1.889001856630123], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#4C72B0"], "edgewidths": [0.3], "offsets": "data01", "yindex": 1, "id": "el12784740207504", "pathtransforms": [[7.0, 0.0, 0.0, 7.0, 0.0, 0.0]], "pathcoordinates": "display", "offsetcoordinates": "data", "zorder": 1, "xindex": 0, "alphas": [null], "facecolors": ["#4C72B0"]}, {"paths": [[[[67677.63476627944, -0.23213106750467813], [67677.63476627944, 0.5005194795665989]], ["M", "L"]], [[[48333.572726737075, -0.24801320925199405], [48333.572726737075, 0.8411336526783275]], ["M", "L"]], [[[52496.69487047096, -0.2487683550341212], [52496.69487047096, 0.8214212443629073]], ["M", "L"]], [[[58507.50020962727, -0.2247 ...

# %%
df_['shootingspp'] = df_["Number of mass shootings"] / df_['pop'] * 1e3

# %% [markdown]
# ## plot the average number of homicide by fire arms per person
# first as a histogram
#
# then against the country GDP, with statistical errors. are there  points that look like outliers?

# %%
fig, ax = plt.subplots()
ax.hist(df_['Number of homicides by firearm'] / df_['pop'])
ax.set_xlabel('homicides by firearm per person');
print (df_[df_['Number of homicides by firearm'] / df_['pop'] >0.000025])
# Out:
#      Country Name  Average total all civilian firearms          pop  \
# 21  United States                          270000000.0  313998379.0
#
#              gdp  Number of homicides by firearm        Country  \
# 21  1.615526e+13                          9146.0  United States
#
#     Guns/100 inhabitants  Number of mass shootings  shootingspp
# 21                  88.8                        78     0.000248

# %%
fig, ax = plt.subplots()

scatter = ax.scatter(df_.gdp / df_['pop'], df_['Number of homicides by firearm'] / df_['pop'] * 1e7)
ax.errorbar(df_.gdp / df_['pop'], df_['Number of homicides by firearm'] / df_['pop'] * 1e7, 
            yerr = np.sqrt(df_['Number of homicides by firearm'] * 1.0) / df_['pop'] * 1e7, fmt = '.')
ax.set_xlabel("gdp")
ax.set_ylabel("Number of homicides by firearm")
labels = ['{0}, {1}'.format(c, n) for c,n in zip(df_["Country"].values, df_["Number of homicides by firearm"].values)]
tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=labels)
mpld3.plugins.connect(fig, tooltip)
mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el127847406359841337883264"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el127847406359841337883264", {"axes": [{"xlim": [8138.5803571235574, 111444.75675427055], "yscale": "linear", "axesbg": "#EAEAF2", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "gdp", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.066894106629205946], "rotation": -0.0, "id": "el12784724912208"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Number of homicides by firearm", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.061883960573476685, 0.5], "rotation": -90.0, "id": "el12784753222608"}], "zoomable": true, "images": [], "xdomain": [8138.5803571235574, 111444.75675427055], "ylim": [-14.728346618809343, 309.03773668447377], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "visible": true, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "visible": true, "fontsize": 10.0, "position": "left", "nticks": 9, "tickvalues": null}], "lines": [], "markers": [{"edgecolor": "#4C72B0", "facecolor": "#4C72B0", "edgewidth": 0.0, "yindex": 1, "coordinates": "data", "zorder": 2.1, "markerpath": [[[0.0, 1.75], [0.46410542500000007, 1.75], [0.9092647738734936, 1.565608960279423], [1.2374368670764582, 1.2374368670764582], [1.565608960279423, 0.9092647738734936], [1.75, 0.46410542500000007], [1.75, 0.0], [1.75, -0.46410542500000007], [1.565608960279423, -0.9092647738734936], [1.2374368670764582, -1.2374368670764582], [0.9092647738734936, -1.565608960279423], [0.46410542500000007, -1.75], [0.0, -1.75], [-0.46410542500000007, -1.75], [-0.9092647738734936, -1.565608960279423], [-1.2374368670764582, -1.2374368670764582], [-1.565608960279423, -0.9092647738734936], [-1.75, -0.46410542500000007], [-1.75, 0.0], [-1.75, 0.46410542500000007], [-1.565608960279423, 0.9092647738734936], [-1.2374368670764582, 1.2374368670764582], [-0.9092647738734936, 1.565608960279423], [-0.46410542500000007, 1.75], [0.0, 1.75]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 1, "xindex": 0, "data": "data01", "id": "el12784756286864pts"}], "id": "el12784720139728", "ydomain": [-14.728346618809343, 309.03773668447377], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#4C72B0"], "edgewidths": [0.3], "offsets": "data01", "yindex": 1, "id": "el12784756284368", "pathtransforms": [[7.0, 0.0, 0.0, 7.0, 0.0, 0.0]], "pathcoordinates": "display", "offsetcoordinates": "data", "zorder": 1, "xindex": 0, "alphas": [null], "facecolors": ["#4C72B0"]}, {"paths": [[[[67677.63476627944, 10.789554897155028], [67677.63476627944, 15.609305305656854]], ["M", "L"]], [[[48333.572726737075, 16.31954211206241], [48333.572726737075, 26.38512981463359]], ["M", "L"]], [[[52496.69487047096, 45.99843068994575], [52496.69487047096, 53.568353082797955]], ["M", "L"]], [[[58507.50020962727, 19.899621526455498], [58507.50020962727, 33.75255356849097]], [ ...

# %% [markdown]
# ## plot the number of  homicides by fire arm against the number of civilian firearms. plot the  US in a different color

# %%
fig, ax = plt.subplots()

scatter = ax.scatter(df_[u'Average total all civilian firearms'] / df_['pop'], 
                     df_['Number of homicides by firearm'] / df_['pop'] * 1e7, alpha = 0.5)
ax.errorbar(df_[u'Average total all civilian firearms'] / df_['pop']  , 
            df_['Number of homicides by firearm'] / df_['pop'] * 1e7, 
            yerr = np.sqrt(df_['Number of homicides by firearm'] * 1.0) 
            / df_['pop'] * 1e17  / df_['gdp'], fmt = '.', alpha = 0.5)
labels = ['{0}, {1}'.format(c, n) for c,n in zip(df_["Country"].values, df_["Number of homicides by firearm"].values)]
tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=labels)
ax.scatter(df_[df_["Country"] == 'United States'][u'Average total all civilian firearms'] / 
           df_[df_["Country"] == 'United States']['pop'], 
                     df_[df_["Country"] == 'United States']['Number of homicides by firearm'] / 
           df_[df_["Country"] == 'United States']['pop'] * 1e7, color='r')

ax.set_xlabel("civilian fire arms per person")
ax.set_ylabel("firearm homicides arms per person")
     
mpld3.plugins.connect(fig, tooltip)
mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el127847563447841478644643"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el127847563447841478644643", {"axes": [{"xlim": [-0.04577725554174035, 0.91121730505844867], "yscale": "linear", "axesbg": "#EAEAF2", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "civilian fire arms per person", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.066894106629205946], "rotation": -0.0, "id": "el12784750822992"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "firearm homicides arms per person", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.061883960573476685, 0.5], "rotation": -90.0, "id": "el12784750689424"}], "zoomable": true, "images": [], "xdomain": [-0.04577725554174035, 0.91121730505844867], "ylim": [-14.76361566019108, 309.77838655349018], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "visible": true, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "visible": true, "fontsize": 10.0, "position": "left", "nticks": 9, "tickvalues": null}], "lines": [], "markers": [{"edgecolor": "#4C72B0", "facecolor": "#4C72B0", "edgewidth": 0.0, "yindex": 1, "coordinates": "data", "zorder": 2.1, "markerpath": [[[0.0, 1.75], [0.46410542500000007, 1.75], [0.9092647738734936, 1.565608960279423], [1.2374368670764582, 1.2374368670764582], [1.565608960279423, 0.9092647738734936], [1.75, 0.46410542500000007], [1.75, 0.0], [1.75, -0.46410542500000007], [1.565608960279423, -0.9092647738734936], [1.2374368670764582, -1.2374368670764582], [0.9092647738734936, -1.565608960279423], [0.46410542500000007, -1.75], [0.0, -1.75], [-0.46410542500000007, -1.75], [-0.9092647738734936, -1.565608960279423], [-1.2374368670764582, -1.2374368670764582], [-1.565608960279423, -0.9092647738734936], [-1.75, -0.46410542500000007], [-1.75, 0.0], [-1.75, 0.46410542500000007], [-1.565608960279423, 0.9092647738734936], [-1.2374368670764582, 1.2374368670764582], [-0.9092647738734936, 1.565608960279423], [-0.46410542500000007, 1.75], [0.0, 1.75]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 0.5, "xindex": 0, "data": "data01", "id": "el12784744560208pts"}], "id": "el12784750820496", "ydomain": [-14.76361566019108, 309.77838655349018], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#4C72B0"], "edgewidths": [0.3], "offsets": "data01", "yindex": 1, "id": "el12784744559824", "pathtransforms": [[7.0, 0.0, 0.0, 7.0, 0.0, 0.0]], "pathcoordinates": "display", "offsetcoordinates": "data", "zorder": 1, "xindex": 0, "alphas": [0.5], "facecolors": ["#4C72B0"]}, {"paths": [[[[0.1341942060309604, 13.183763192920603], [0.1341942060309604, 13.215097009891279]], ["M", "L"]], [[[0.2965602217131667, 21.228817143929277], [0.2965602217131667, 21.475854782766724]], ["M", "L"]], [[[0.28632644466439305, 49.76264428717203], [0.28632644466439305, 49.804139485571675]], ["M", "L"]], [[[0.11624637937238401, 26.6143654227215],  ...

# %% [markdown]
# ## plot the number of  mass shootings against the number of civilian firearms. plot the  US in a different color

# %%
fig, ax = plt.subplots()

scatter = ax.scatter(df_[u'Average total all civilian firearms'] / df_['pop'], 
                     df_['Number of mass shootings'] / df_['pop'] * 1e7, alpha=0.5)
ax.errorbar(df_[u'Average total all civilian firearms'] / df_['pop'], 
                     df_['Number of mass shootings'] / df_['pop'] * 1e7, 
            yerr = np.sqrt(df_['Number of mass shootings'] * 1.0) / df_['pop'] * 1e7, 
            fmt = '.', alpha=0.5)
ax.scatter(df_[df_["Country"] == 'United States'][u'Average total all civilian firearms'] / 
           df_[df_["Country"] == 'United States']['pop'] , 
                     df_[df_["Country"] == 'United States']['Number of mass shootings']  / 
           df_[df_["Country"] == 'United States']['pop'] * 1e7, color='r', alpha=0.5)
labels = ['{0}, {1}'.format(c, n) for c,n in zip(df_["Country"].values, 
                                                 df_["Number of mass shootings"].values)]
tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=labels)

mpld3.plugins.connect(fig, tooltip)
mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el127847559590564094169132"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el127847559590564094169132", {"axes": [{"xlim": [-0.04577725554174035, 0.91121730505844867], "yscale": "linear", "axesbg": "#EAEAF2", "texts": [], "zoomable": true, "images": [], "xdomain": [-0.04577725554174035, 0.91121730505844867], "ylim": [-0.54903673975411316, 11.27222922431393], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "visible": true, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "visible": true, "fontsize": 10.0, "position": "left", "nticks": 8, "tickvalues": null}], "lines": [], "markers": [{"edgecolor": "#4C72B0", "facecolor": "#4C72B0", "edgewidth": 0.0, "yindex": 1, "coordinates": "data", "zorder": 2.1, "markerpath": [[[0.0, 1.75], [0.46410542500000007, 1.75], [0.9092647738734936, 1.565608960279423], [1.2374368670764582, 1.2374368670764582], [1.565608960279423, 0.9092647738734936], [1.75, 0.46410542500000007], [1.75, 0.0], [1.75, -0.46410542500000007], [1.565608960279423, -0.9092647738734936], [1.2374368670764582, -1.2374368670764582], [0.9092647738734936, -1.565608960279423], [0.46410542500000007, -1.75], [0.0, -1.75], [-0.46410542500000007, -1.75], [-0.9092647738734936, -1.565608960279423], [-1.2374368670764582, -1.2374368670764582], [-1.565608960279423, -0.9092647738734936], [-1.75, -0.46410542500000007], [-1.75, 0.0], [-1.75, 0.46410542500000007], [-1.565608960279423, 0.9092647738734936], [-1.2374368670764582, 1.2374368670764582], [-0.9092647738734936, 1.565608960279423], [-0.46410542500000007, 1.75], [0.0, 1.75]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]], "alpha": 0.5, "xindex": 0, "data": "data01", "id": "el12784757872144pts"}], "id": "el12784756380048", "ydomain": [-0.54903673975411316, 11.27222922431393], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#4C72B0"], "edgewidths": [0.3], "offsets": "data01", "yindex": 1, "id": "el12784757872208", "pathtransforms": [[7.0, 0.0, 0.0, 7.0, 0.0, 0.0]], "pathcoordinates": "display", "offsetcoordinates": "data", "zorder": 1, "xindex": 0, "alphas": [0.5], "facecolors": ["#4C72B0"]}, {"paths": [[[[0.1341942060309604, 0.8799620067603962], [0.1341942060309604, 2.6398860202811885]], ["M", "L"]], [[[0.2965602217131667, 0.0], [0.2965602217131667, 2.3724817737053336]], ["M", "L"]], [[[0.28632644466439305, 0.575530542038981], [0.28632644466439305, 1.7265916261169432]], ["M", "L"]], [[[0.11624637937238401, 0.0], [0.11624637937238401, 0.0]], ["M", "L"]], [[[0.443297535210292, 1.0819903498317687], [0.443297535210292, 6.3063019036730985]], ["M", "L"]], [[[0.28937040462663677, 0.5407434682957137], [0.28937040462663677, 1.2868590872409396]], ["M", "L"]], [[[0.31084543579989227, 0.5413993325172948], [0.31084543579989227, 1.199335107962102]], ["M", "L"]], [[[0.22634653781693834, 0.0], [0.22634653781693834, 0.0]], ["M", "L"]], [[[0.05644955294978147, 0.0], [0.05644955294978147, 0.0]], ["M", "L"]], [[[0.28062210803327553, 0.0], [0.28062210803327553, 0.0]], ["M" ...

# %% [markdown]
# # Modeling
#
# ## fit a line to the Number of mass shootings  per person as a function of Average total all civilian firearms per person. Before you do it it is a good idea to make sure that both quantities are roughly of the same order of magnitude (unity). Use
#     - analytical solution
#     - polyfit
#     - statsmodels OLS
#     - statsmodels WLS
#     - seaborn
#
# in each case show your model parameters
#
# at least for statsmodels plot a summary of your model and point out metrics that show if the fit is good.
#
# plot each model.
#
# Use the seaborn python package to plot the regression confidence intervals.
#
# ## Extra credit: calculate the confidence interval by hand and also plot them (you can use pl.fill_between)

# %%
import statsmodels.api as st

# %%
df_['x'] = df_[u'Average total all civilian firearms'] / df_['pop']
df_['y'] = df_[u'Number of mass shootings'] / df_['pop'] * 1e7

# %%
modelOLS = st.OLS(exog=st.add_constant(df_.x), endog=df_.y).fit()

# %%
modelOLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.199
# Model:                            OLS   Adj. R-squared:                  0.159
# Method:                 Least Squares   F-statistic:                     4.971
# Date:                Thu, 12 Oct 2017   Prob (F-statistic):             0.0374
# Time:                        07:39:03   Log-Likelihood:                -39.232
# No. Observations:                  22   AIC:                             82.46
# Df Residuals:                      20   BIC:                             84.65
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.3149      0.515      0.612      0.548        -0.759     1.388
# x              3.9106      1.754      2.230      0.037         0.252     7.569
# ==============================================================================
# Omnibus:                       34.840   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.018
# Skew:                           2.733   Prob(JB):                     7.71e-20
# Kurtosis:                      11.133   Cond. No.                         5.74
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import scipy as sp 
from scipy import stats
tp = sp.stats.t.ppf(0.975, len(df_.x - 1 - modelOLS.df_model))

# %%
def serr(x, xhat=None): 
    if xhat is None:
        return np.sqrt(((x - x.mean())**2 / (len(x) - 2)).sum())
    else: 
        return np.sqrt(((x - xhat)**2 / (len(x) - 2)).sum())

# %%
n = len(df_.x)
ci = tp * serr(df_.y, modelOLS.predict()) * np.sqrt( 1.0 / n + ((df_.x - df_.x.mean())**2 / 
                                       (n - 1) / serr(df_.x)**2))
#modelOLS.params[1] * np.sort(df_.x) + ci + modelOLS.params[0], df_.x

# %%
df_.yerr = np.sqrt(df_[u'Number of mass shootings'] 
                             / df_['pop'] * 1e7) + 1
df_.w = 1.0 / df_.yerr
~np.isfinite(df_.w)


modelWLS = st.WLS(exog=st.add_constant(df_.x), endog=df_.y,
      weights = 1.0/df_.w).fit()

# %%
modelWLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.086
# Model:                            WLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     1.877
# Date:                Thu, 12 Oct 2017   Prob (F-statistic):              0.186
# Time:                        07:39:09   Log-Likelihood:                -45.435
# No. Observations:                  22   AIC:                             94.87
# Df Residuals:                      20   BIC:                             97.05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          1.0677      0.701      1.524      0.143        -0.394     2.529
# x              2.8510      2.081      1.370      0.186        -1.490     7.192
# ==============================================================================
# Omnibus:                       43.390   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              155.626
# Skew:                           3.359   Prob(JB):                     1.61e-34
# Kurtosis:                      14.164   Cond. No.                         5.51
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
modelOLS.conf_int()[0].x, modelWLS.conf_int()[0].x
# Out:
# (0.25180711334806283, -1.4898835608426499)

# %%
fig = pl.figure()
ax = fig.add_subplot(221)
ax.plot(df_.x, df_.y, '.')

ax = fig.add_subplot(222)
ax.plot(df_.x, df_.y, '.')
ax.plot(df_.x,
        modelOLS.fittedvalues, '.')
ax.plot([df_.x.min(), df_.x.max()],
        modelOLS.params[1] * np.array([df_.x.min(), df_.x.max()]) +
        modelOLS.params[0], 'k-', alpha=0.6)

ax = fig.add_subplot(223)
ax.plot(df_.x, df_.y, '.')
ax.plot(df_.x,
        modelOLS.fittedvalues, '.')
ax.plot([df_.x.min(), df_.x.max()],
        modelOLS.params[1] * np.array([df_.x.min(), df_.x.max()]) +
        modelOLS.params[0], 'k-')
ax.fill_between(np.sort(df_.x),
            modelOLS.params[1] * np.sort(df_.x) + ci + modelOLS.params[0],
                 modelOLS.params[1] * np.sort(df_.x) - ci + modelOLS.params[0], 
                color='k', alpha=0.2)
ax = fig.add_subplot(224)
ax.plot(df_.x, df_.y, '.')
ax.plot(df_.x,
        modelOLS.fittedvalues, '.')
ax.plot([df_.x.min(), df_.x.max()],
        modelOLS.params[1] * np.array([df_.x.min(), df_.x.max()]) +
        modelOLS.params[0], 'k-')
ax.fill_between(np.sort(df_.x),
            modelOLS.params[1] * np.sort(df_.x) + ci + modelOLS.params[0],
                 modelOLS.params[1] * np.sort(df_.x) - ci + modelOLS.params[0], 
                color='k', alpha=0.2)
ax.fill_between([df_.x.min(), df_.x.max()],
        (modelOLS.conf_int()[0].x) * np.array([df_.x.min(), df_.x.max()]) +
        modelOLS.conf_int()[0].const,
        (modelOLS.conf_int()[1].x) * np.array([df_.x.min(), df_.x.max()]) +
        modelOLS.conf_int()[1].const, color='k', alpha=0.3)
pl.figure()
import seaborn  as sns
sns.regplot(x="x", y="y", data=df_);

xx = sm.add_constant(np.sort(df_.x)) # constant intercept term
axsort = np.argsort(df_.x)
xsort = df_.x[axsort]
y_hat = modelOLS.predict(xx) # x is an array from line 12 above

y_err = df_.y[axsort] - y_hat

mean_x = xx.T[1].mean()

nn = len(xx)

dof = nn - modelOLS.df_model - 1

t = stats.t.ppf(1-0.025, df=dof)

s_err = np.sum(np.power(y_err, 2))

conf = t * np.sqrt((s_err/(nn-2))*(1.0/nn + (np.power((xsort-mean_x),2) / 
     ((np.sum(np.power(xsort,2))) - nn*(np.power(mean_x,2))))))
upper = y_hat + conf
lower = y_hat - conf
pl.figure()
pl.plot(df_.x, df_.y, '.')
pl.plot(df_.x,
        modelOLS.fittedvalues, '-')
pl.fill_between(df_.x[axsort], lower, upper, color='#888888', alpha=0.4)
sns.regplot(x="x", y="y", data=df_);

# %%
fig = pl.figure()
ax = fig.add_subplot(221)
ax.errorbar(df_.x, df_.y, yerr=df_.yerr, fmt='.')

ax = fig.add_subplot(222)
ax.errorbar(df_.x, df_.y, yerr=df_.yerr, fmt='.')
ax.plot(df_.x,
        modelWLS.fittedvalues, '.')
ax.plot([df_.x.min(), df_.x.max()],
        modelWLS.params[1] * np.array([df_.x.min(), df_.x.max()]) +
        modelWLS.params[0], 'k-', alpha=0.6)

ax = fig.add_subplot(223)
ax.errorbar(df_.x, df_.y, yerr=df_.yerr, fmt='.')
ax.plot(df_.x,
        modelWLS.fittedvalues, '.')
ax.plot([df_.x.min(), df_.x.max()],
        modelOLS.params[1] * np.array([df_.x.min(), df_.x.max()]) +
        modelOLS.params[0], 'r-')
ax.plot([df_.x.min(), df_.x.max()],
        modelWLS.params[1] * np.array([df_.x.min(), df_.x.max()]) +
        modelWLS.params[0], 'k-')
ax.fill_between(np.sort(df_.x),
            modelWLS.params[1] * np.sort(df_.x) + ci + modelWLS.params[0],
                 modelWLS.params[1] * np.sort(df_.x) - ci + modelWLS.params[0], 
                color='k', alpha=0.2)

ax = fig.add_subplot(224)
ax.errorbar(df_.x, df_.y, yerr=df_.yerr, fmt='.')
ax.plot(df_.x,
        modelWLS.fittedvalues, '.')
ax.plot([df_.x.min(), df_.x.max()],
        modelWLS.params[1] * np.array([df_.x.min(), df_.x.max()]) +
        modelWLS.params[0], 'k-')
ax.fill_between(np.sort(df_.x),
            modelWLS.params[1] * np.sort(df_.x) + ci + modelWLS.params[0],
                 modelWLS.params[1] * np.sort(df_.x) - ci + modelWLS.params[0], 
                color='k', alpha=0.2)
ax.fill_between([df_.x.min(), df_.x.max()],
        (modelWLS.conf_int()[0].x) * np.array([df_.x.min(), df_.x.max()]) +
        modelWLS.conf_int()[0].const,
        (modelWLS.conf_int()[1].x) * np.array([df_.x.min(), df_.x.max()]) +
        modelWLS.conf_int()[1].const, color='k', alpha=0.3)
pl.figure()

xx = sm.add_constant(np.sort(df_.x)) # constant intercept term
axsort = np.argsort(df_.x)
xsort = df_.x[axsort]
y_hatW = modelWLS.predict(xx) # x is an array from line 12 above

y_errW = df_.y[axsort] - y_hatW


s_err = np.sum(np.power(y_errW, 2))

conf = t * np.sqrt((s_err/(nn-2))*(1.0/nn + (np.power((xsort-mean_x),2) / 
     ((np.sum(np.power(xsort,2))) - nn*(np.power(mean_x,2))))))
upperW = y_hatW + conf
lowerW = y_hatW - conf
pl.figure()
pl.errorbar(df_.x, df_.y, yerr=df_.yerr, fmt='.')
pl.plot(df_.x,
        modelWLS.fittedvalues, '-')
pl.fill_between(df_.x[axsort], lowerW, upperW, color='#aaaaaa', alpha=0.5)
pl.fill_between(df_.x[axsort], lower, upper, color='#888888', alpha=0.3)
sns.regplot(x="x", y="y", data=df_);

# %%
df_[df_["Number of homicides by firearm"] > df_["Number of homicides by firearm"].mean() + 
    3.0 * df_["Number of homicides by firearm"].std()]
# Out:
#      Country Name  Average total all civilian firearms          pop  \
# 21  United States                          270000000.0  323127513.0
#
#              gdp  Number of homicides by firearm        Country  \
# 21  1.856910e+13                          9146.0  United States
#
#     Guns/100 inhabitants  Number of mass shootings  shootingspp         x  \
# 21                  88.8                        78     0.000241  0.835583
#
#            y
# 21  2.413908

# %%
df_[df_["Number of mass shootings"] > df_["Number of mass shootings"].mean() + 
    3.0 * df_["Number of mass shootings"].std()]
# Out:
#      Country Name  Average total all civilian firearms          pop  \
# 21  United States                          270000000.0  323127513.0
#
#              gdp  Number of homicides by firearm        Country  \
# 21  1.856910e+13                          9146.0  United States
#
#     Guns/100 inhabitants  Number of mass shootings  shootingspp         x  \
# 21                  88.8                        78     0.000241  0.835583
#
#            y
# 21  2.413908

# %%
df_[df_["Average total all civilian firearms"] > df_["Average total all civilian firearms"].mean() + 
    3.0 * df_["Average total all civilian firearms"].std()]
# Out:
#      Country Name  Average total all civilian firearms          pop  \
# 21  United States                          270000000.0  323127513.0
#
#              gdp  Number of homicides by firearm        Country  \
# 21  1.856910e+13                          9146.0  United States
#
#     Guns/100 inhabitants  Number of mass shootings  shootingspp         x  \
# 21                  88.8                        78     0.000241  0.835583
#
#            y
# 21  2.413908

# %%
df_[df_["x"] > df_["x"].mean() + 
    3.0 * df_["x"].std()]
# Out:
#      Country Name  Average total all civilian firearms          pop  \
# 21  United States                          270000000.0  323127513.0
#
#              gdp  Number of homicides by firearm        Country  \
# 21  1.856910e+13                          9146.0  United States
#
#     Guns/100 inhabitants  Number of mass shootings  shootingspp         x  \
# 21                  88.8                        78     0.000241  0.835583
#
#            y
# 21  2.413908

# %%
df_['yerr'] = np.sqrt(df_['Number of mass shootings'] * 1.0 / df_['pop'] * 1e7)

# %%
sns.jointplot(x="x", y="y", data=df_, kind="reg");

# %% [markdown]
# ## Use the stsatsmodels.gaphics package to plot the influence plot.
# Read the package documentation to learn how to read this plot and extract the countries with the highest influence

# %%
sm.graphics.influence_plot(modelOLS, alpha  = 0.05, criterion="cooks");

# %% [markdown]
# ## Extra credit: calculate from scratch the stanrdardized residuals and the H leverage for the WLS model and discuss if there are any differences

# %%
print(df_.iloc[14])
# Out:
# Country Name                           New Zealand
# Average total all civilian firearms         925000
# pop                                     4.6927e+06
# gdp                                    1.85017e+11
# Number of homicides by firearm                   7
# Country                                New Zealand
# Guns/100 inhabitants                          22.6
# Number of mass shootings                         3
# shootingspp                            0.000639291
# x                                         0.197115
# y                                          6.39291
# yerr                                       2.52842
# Name: 14, dtype: object

# %%
def cooks(data, model):
    mysum = 0
    for d,m in zip(data.y, model.fittedvalues.values):
        mysum += (data.y - d - model.fittedvalues.values + m)**2 
        
    return mysum / model.params.size / len(data.y) / (data.y - model.fittedvalues.values)**2

# %% [markdown]
# # Discuss your findings
